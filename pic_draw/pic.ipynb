# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
# 绘制数据
loss = [22.31, 6.17, 5.9, 5.93, 6.02, 5.89, 5.96, 5.69, 6.05, 5.78, 5.60, 5.77, 5.65, 5.58, 4.91, 5.16, 5.24, 4.53, 4.17, 4.43,
        4.08, 4.03, 3.25, 3.43, 3.84, 3.07, 3.17, 3.41, 2.59, 2.60, 2.95, 2.82, 2.29, 1.94, 2.24, 1.94, 2.28, 2.30, 2.55, 1.98, 2.03,
        2.22, 1.73, 1.97, 1.88, 1.86, 2.27, 1.24, 1.69, 1.2, 1.41, 1.37, 1.52, 1.46, 1.14, 1.35, 1.12, 1.09, 1.07, 1.14, 1.484, 1.06,
        1.29, 1.31, 1.62, 1.43, 1.24, 1.05, 1.28, 1.04, 1.34, 1.29, 1.56, 1.53]

x = [i for i in range(len(loss))]

# 创建图表
fig, ax = plt.subplots(figsize=(10, 6))

# 设置白色背景
ax.set_facecolor('white')

# 绘制数据曲线
ax.plot(x, loss, label='train_loss', color='blue')

# 添加标题和标签
ax.set_title('Training Loss', fontsize=16)
ax.set_xlabel('100 times for batch', fontsize=12)
ax.set_ylabel('Loss', fontsize=12)

# 显示横纵格子
ax.grid(True)

# 添加图例
ax.legend()

plt.savefig('Training_Loss')

# 显示图表
plt.show()

# %%
# 绘制数据
train_CER = [14.25,
13.6875,
15,
13.25,
13.4375,
13.8125,
13.4375,
12.1875,
13.75,
14.15,
13.5625,
13.25,
14,
14.625,
13.875,
13.8125,
14.25,
12.25,
11.75,
12.15,
10.9375,
13.75,
9.375,
13.18,
10.165,
11.75,
11.06,
12.1875,
10.75,
9.4375,
10.875,
11.1875,
8.875,
8.0625,
8.125,
7.625,
8.25,
8.25,
9.5,
7.5,
8.25,
9.31,
7.625,
8.1875,
8.025,
6.8125,
9.1875,
6.6875,
7.5,
7.025,
7.25,
6.625,
6.375,
7.6875,
5.5,
5.875,
6.1875,
5.0625,
6,
5.5,
6.25,
4.8125,
5.75,
5.25,
8.125,
6.75,
6.25,
5.125,
7.25,
6.4,
7,
5.5625,
8.875,
8,
6.5,
6.5,
6.125,
6.75,
7.81,
6.06,
7.56,
5.4375,
5.125,
4.6875,
4.765,
4.966
]

x = [i for i in range(len(train_CER))]

# 创建图表
fig, ax = plt.subplots(figsize=(10, 6))

# 设置白色背景
ax.set_facecolor('white')

# 绘制数据曲线
ax.plot(x, train_CER, label='train_CER', color='blue')

# 添加标题和标签
ax.set_title('Training CER', fontsize=16)
ax.set_xlabel('100 times for batch', fontsize=12)
ax.set_ylabel('CER', fontsize=12)

# 显示横纵格子
ax.grid(True)

# 添加图例
ax.legend()

plt.savefig('CER')

# 显示图表
plt.show()

# %%
# 绘制数据
test_CER = [24.122, 14.11, 12.91, 12.16, 10.65, 9.67, 8.8375, 8.975, 8.8875, 8.7, 9, 8.7125, 8.641]

x = [i for i in range(len(test_CER))]

# 创建图表
fig, ax = plt.subplots(figsize=(10, 6))

# 设置白色背景
ax.set_facecolor('white')

# 绘制数据曲线
ax.plot(x, test_CER, label='test_CER', color='red')

# 添加标题和标签
ax.set_title('test_CER', fontsize=16)
ax.set_xlabel('1000 times for batch', fontsize=12)
ax.set_ylabel('test_CER', fontsize=12)

# 显示横纵格子
ax.grid(True)

# 添加图例
ax.legend()

plt.savefig('Training_Loss')

# 显示图表
plt.show()
